# %% [markdown]
# # Notebook to Train Custom YOLO Models
#
# This notebook is designed to help you train your own YOLO models from scratch or fine-tune existing ones.
# You can use either:
#
# - **Local datasets** (e.g., in YOLO format stored on your Google Drive or GitHub)
# - **Datasets from Roboflow**, which can be easily imported via a download link
# - **Example dataset**, from a linked github repository
#
# The workflow includes:
# - Loading and organizing your dataset
# - Writing a custom `.yaml` config file
# - Launching training with the `ultralytics` YOLO implementation
# - (Optional) Exporting and evaluating your trained model
#
# This is ideal for training models on custom objects — whether you're working with animals, vehicles, tools, or underwater footage.
#
# ---
#
# Make sure your dataset is in the correct YOLO structure:
#
# ```
# dataset/
# ├── train/
# │   ├── images/
# │   └── labels/
# ├── valid/
# │   ├── images/
# │   └── labels/
# ├── test/   # optional
# │   ├── images/
# │   └── labels/
# └── data.yaml
# ```

# %% [markdown]
# # Import libraries

# %%
import os
import random
import shutil
import math
import glob
from IPython.display import Image, display
import numpy as np
import time  # Import the time module
from google.colab import runtime
from google.colab import drive
from pathlib import Path
import zipfile
import platform
import gdown
import sys
from pathlib import Path
import sys

from __future__ import annotations
import os, shutil, random, math
from tempfile import mkdtemp
from typing import Optional, Tuple, Dict, List, Sequence

from collections import Counter, defaultdict

# %%
# !nvidia-smi
# Out:
# Mon Mar  2 15:54:51 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Pip install method (recommended)

# !pip install 'ultralytics'
# !pip install ultralytics==8.3.195
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO
from IPython.display import display, Image

##tiling
# !pip install --upgrade git+https://github.com/Jordan-Pierce/yolo-tiling.git
import sys
sys.path.append('/content/yolo-tiling')

from yolo_tiler import YoloTiler, TileConfig, TileProgress
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.5/112.6 GB disk)
# Collecting git+https://github.com/Jordan-Pierce/yolo-tiling.git
#   Cloning https://github.com/Jordan-Pierce/yolo-tiling.git to /tmp/pip-req-build-jshwouy8
#   Running command git clone --filter=blob:none --quiet https://github.com/Jordan-Pierce/yolo-tiling.git /tmp/pip-req-build-jshwouy8
#   Resolved https://github.com/Jordan-Pierce/yolo-tiling.git to commit 7808dc761b6e064dc4963025a719eb095827b656
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from yolo-tiling==0.0.27) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from yolo-tiling==0.0.27) (4.67.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from yolo-tiling==0.0.27) (2.2.2)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from yolo-tiling==0.0.27) (2.1.2)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from yolo-tiling==0.0.27) (1.5.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from yolo-tiling==0.0.27) (4.13.0.92)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from yolo-tiling==0.0.27) (3.10.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from yolo-tiling==0.0.27) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->yolo-tiling==0.0.27) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->yolo-tiling==0.0.27) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->yolo-tiling==0.0.27) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->yolo-tiling==0.0.27) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->yolo-tiling==0.0.27) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->yolo-tiling==0.0.27) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->yolo-tiling==0.0.27) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->yolo-tiling==0.0.27) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->yolo-tiling==0.0.27) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->yolo-tiling==0.0.27) (2025.3)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->yolo-tiling==0.0.27) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->yolo-tiling==0.0.27) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio->yolo-tiling==0.0.27) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio->yolo-tiling==0.0.27) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->yolo-tiling==0.0.27) (0.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->yolo-tiling==0.0.27) (1.17.0)

# %%
### Clone the folder with the functions
# !git clone https://github.com/albiangela/train-custom-YOLO-Colab.git
import sys
sys.path.append("/content/train-custom-YOLO-Colab/utils")
# Out:
# fatal: destination path 'train-custom-YOLO-Colab' already exists and is not an empty directory.

# %% [markdown]
# ### 🔗 Connect to Your Google Drive
#
# Google Colab is a cloud-based Python environment that lets you run code in your browser, with free access to GPUs.
#
# To access your datasets or save model outputs, you’ll need to connect Colab to your Google Drive.
# This allows you to read and write files directly from your Drive, making it easier to store large datasets or export trained models.
#
# Run the cell below to authorize access.

# %%
# Mount google drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !zip -r /content/Keypoint_reduced_clean.zip \
/content/drive/MyDrive/Keypoint_reduced
# Out:
# Scanning files
#   adding: content/drive/MyDrive/Keypoint_reduced/ (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/data.yaml (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/ (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/ (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000018_f784_x4245_y4815_png.rf.4dc7cf91271ec93955e81bf4dc042083.txt (deflated 44%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000312_f3343_x5260_y2060_png.rf.02eaea4ba125f17549c6cc886cfd5b31.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000409_f12066_x4872_y5685_png.rf.be02c748432a2837f309fe6faf8669cc.txt (deflated 44%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000432_f1577_x4683_y2927_png.rf.c6d95dd64352bfb3a0b67b99809c37c5.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000228_f1695_x1045_y2033_png.rf.58d50a87e9ed925ada912613d3806d3a.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000270_f3092_x2611_y2154_png.rf.4ba15b2ff2544fa62f6753a19a75cfe1.txt (deflated 45%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000402_f1631_x5897_y3003_png.rf.54f2c10595c0341215c0f338b6d7350d.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000104_f285_x4656_y2212_png.rf.ea868188050b4c88263a6ac3a7a0508f.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000340_f1563_x1245_y958_png.rf.4169ba79712dbe2fbcd7772f16294d14.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000036_f432_x433_y4921_png.rf.ecf5cbe1a620bbbb586cdf7b5829b52c.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000054_f603_x5436_y4521_png.rf.fac72078f1afd1f8df20d79f00299049.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000067_f2172_x356_y1393_png.rf.5ee46798e33ed3d5e102cd0849295dea.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000401_f5444_x1577_y1433_png.rf.9cf19450fc8954412fc85536cc70b137.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000058_f5425_x4485_y3242_png.rf.603e917cad69e4389861d84739a914a4.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000582_f3438_x3705_y4712_png.rf.29fa8a95342d2926bb7363ba81ada2d2.txt (deflated 44%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000662_f8984_x2336_y3974_png.rf.87318d5130406c10c7993e69070befdf.txt (deflated 38%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000369_f7475_x4086_y5598_png.rf.e00df4e56eb77bfae4bfc1a89b67a30b.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000776_f283_x4422_y5589_png.rf.bc08a38ef84d4c08b552b1787b5eba9d.txt (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000138_f6133_x700_y1960_png.rf.b0740c149f49ee14fade89535846fa68.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000650_f4857_x2758_y2324_png.rf.bc9e0872ccc4f0af241fdcbe6f9d175f.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000084_f9551_x1273_y2964_png.rf.74d57f4990946e7ecb874e1845e5202c.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000102_f2229_x4466_y781_png.rf.98464aa20d40714cdfc70ed967949cd6.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000036_f6013_x4183_y4886_png.rf.d036864d59aaf88e840a91e78a8d305e.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000597_f1941_x2768_y3491_png.rf.f17409a402808ad1523cf7e22108264c.txt (deflated 44%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000111_f6274_x90_y5442_png.rf.42aa87dc3c76be833d10639faaa79807.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000164_f5897_x1680_y3934_png.rf.f0f44a524383fc88f24755861a860686.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000661_f11844_x3543_y5889_png.rf.b063ca479bdbfc0d007fef1252f942ee.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000177_f1908_x5870_y1903_png.rf.78400a54deedf711dc693cee1b5d7b64.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000104_f1633_x4299_y3794_png.rf.89a6b44410d37a78225b2d06d5e103c0.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000478_f4395_x1190_y3342_png.rf.760fdb1cf5423dadf2a9bb8515d8fa78.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000119_f2221_x4928_y1569_png.rf.aeab995fa4c5d86cb4f0f8fc94710b5c.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000026_f208_x5725_y3557_png.rf.cd761af402475f4e7e7dc1c6cc85990c.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000246_f5363_x41_y5902_png.rf.9b591488d5d70617fa710d639f4bfbaf.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000029_f10532_x3637_y4146_png.rf.2241ae3bcb0d6cf1b8496563afc90fb5.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000789_f5160_x541_y3104_png.rf.27b5a9618b353461c2bbd6081024e96a.txt (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000209_f11887_x2291_y4501_png.rf.8cc3ba7346d24f7ade9d584ac88f5679.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000233_f14_x4056_y5403_png.rf.b055d73a6e708e3bbec83f968e4f5114.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/labels/tile_000434_f5399_x3682_y514_png.rf.68ea3366bb5c46a37bb97f45c5bebba9.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/ (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000036_f432_x433_y4921_png.rf.ecf5cbe1a620bbbb586cdf7b5829b52c.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000246_f5363_x41_y5902_png.rf.9b591488d5d70617fa710d639f4bfbaf.jpg (deflated 9%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000409_f12066_x4872_y5685_png.rf.be02c748432a2837f309fe6faf8669cc.jpg (deflated 10%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000233_f14_x4056_y5403_png.rf.b055d73a6e708e3bbec83f968e4f5114.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000029_f10532_x3637_y4146_png.rf.2241ae3bcb0d6cf1b8496563afc90fb5.jpg (deflated 6%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000402_f1631_x5897_y3003_png.rf.54f2c10595c0341215c0f338b6d7350d.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000582_f3438_x3705_y4712_png.rf.29fa8a95342d2926bb7363ba81ada2d2.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000228_f1695_x1045_y2033_png.rf.58d50a87e9ed925ada912613d3806d3a.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000177_f1908_x5870_y1903_png.rf.78400a54deedf711dc693cee1b5d7b64.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000104_f1633_x4299_y3794_png.rf.89a6b44410d37a78225b2d06d5e103c0.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000401_f5444_x1577_y1433_png.rf.9cf19450fc8954412fc85536cc70b137.jpg (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000036_f6013_x4183_y4886_png.rf.d036864d59aaf88e840a91e78a8d305e.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000104_f285_x4656_y2212_png.rf.ea868188050b4c88263a6ac3a7a0508f.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000138_f6133_x700_y1960_png.rf.b0740c149f49ee14fade89535846fa68.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000789_f5160_x541_y3104_png.rf.27b5a9618b353461c2bbd6081024e96a.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000478_f4395_x1190_y3342_png.rf.760fdb1cf5423dadf2a9bb8515d8fa78.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000111_f6274_x90_y5442_png.rf.42aa87dc3c76be833d10639faaa79807.jpg (deflated 10%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000058_f5425_x4485_y3242_png.rf.603e917cad69e4389861d84739a914a4.jpg (deflated 32%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000054_f603_x5436_y4521_png.rf.fac72078f1afd1f8df20d79f00299049.jpg (deflated 23%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000084_f9551_x1273_y2964_png.rf.74d57f4990946e7ecb874e1845e5202c.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000209_f11887_x2291_y4501_png.rf.8cc3ba7346d24f7ade9d584ac88f5679.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000597_f1941_x2768_y3491_png.rf.f17409a402808ad1523cf7e22108264c.jpg (deflated 10%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000312_f3343_x5260_y2060_png.rf.02eaea4ba125f17549c6cc886cfd5b31.jpg (deflated 57%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000026_f208_x5725_y3557_png.rf.cd761af402475f4e7e7dc1c6cc85990c.jpg (deflated 23%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000102_f2229_x4466_y781_png.rf.98464aa20d40714cdfc70ed967949cd6.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000119_f2221_x4928_y1569_png.rf.aeab995fa4c5d86cb4f0f8fc94710b5c.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000340_f1563_x1245_y958_png.rf.4169ba79712dbe2fbcd7772f16294d14.jpg (deflated 77%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000661_f11844_x3543_y5889_png.rf.b063ca479bdbfc0d007fef1252f942ee.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000270_f3092_x2611_y2154_png.rf.4ba15b2ff2544fa62f6753a19a75cfe1.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000662_f8984_x2336_y3974_png.rf.87318d5130406c10c7993e69070befdf.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000432_f1577_x4683_y2927_png.rf.c6d95dd64352bfb3a0b67b99809c37c5.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000434_f5399_x3682_y514_png.rf.68ea3366bb5c46a37bb97f45c5bebba9.jpg (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000776_f283_x4422_y5589_png.rf.bc08a38ef84d4c08b552b1787b5eba9d.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000067_f2172_x356_y1393_png.rf.5ee46798e33ed3d5e102cd0849295dea.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000018_f784_x4245_y4815_png.rf.4dc7cf91271ec93955e81bf4dc042083.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000164_f5897_x1680_y3934_png.rf.f0f44a524383fc88f24755861a860686.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000369_f7475_x4086_y5598_png.rf.e00df4e56eb77bfae4bfc1a89b67a30b.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/test/images/tile_000650_f4857_x2758_y2324_png.rf.bc9e0872ccc4f0af241fdcbe6f9d175f.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/ (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/ (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000021_f10668_x5448_y3734_png.rf.6b1ab307a682df5347f9a2cd54b28ba4.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000475_f5553_x132_y4257_png.rf.59208821fc0246e9ff1d9104d3e7b528.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000230_f276_x5855_y598_png.rf.e8fcdc046d436063ff606b41c2b57095.jpg (deflated 6%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000173_f6211_x286_y583_png.rf.40a59f1d589582b1e3ffed85d881453c.jpg (deflated 5%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000326_f1269_x4183_y1796_png.rf.64c2be30556e4e0d3a307728f7ebce8d.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000190_f12025_x605_y1929_png.rf.0153aa7a2193da85331152164274f99d.jpg (deflated 25%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000934_f2372_x2190_y2841_png.rf.e3b5ab96534d334df615f4cd32b23824.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000345_f2123_x5321_y2556_png.rf.53713aed91d3c505b6534a8954b692de.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000506_f2653_x3003_y3487_png.rf.371bd6d81b709f97006b6aefdde520ee.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000473_f958_x5839_y3649_png.rf.33ad949c6adde124ec9659dc43ac48aa.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000058_f10535_x889_y665_png.rf.6eef0bd5d0248ac3d666b9ab3b26f094.jpg (deflated 20%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000099_f7625_x3286_y5834_png.rf.bef33a448bd6e5bed977ccf86cf1b1ac.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000798_f11448_x2566_y4674_png.rf.e7949b94852f4b4390d1790ec8cbf7ba.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000083_f2281_x1762_y2776_png.rf.b323285b75194011a7396dd9685249dd.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000031_f2212_x3325_y3684_png.rf.5d4bf6c57fb265e77cf479b9cfffc40a.jpg (deflated 73%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000540_f2350_x3126_y1920_png.rf.a53ed397f0f4e1162cd072eb128d6591.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000008_f6763_x4192_y6025_png.rf.6a4b2a20c14030ba9ec9320094ce1e7d.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000239_f2128_x4961_y5577_png.rf.34b6cd2fe8f672c481ce7e32df6ae97b.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000056_f326_x1467_y844_png.rf.f5fd0e8b15c9f365649b8b9e98c71751.jpg (deflated 23%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000214_f395_x2192_y3127_png.rf.579c28d6ce50a7c533b479fe71ca6612.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000033_f8647_x4091_y980_png.rf.16887f5f86a538af6bcc5413a0804ba4.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000847_f11214_x4384_y1887_png.rf.92142fcd73cb1f26deac53af692d094b.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000313_f10813_x5153_y2380_png.rf.bc206ee4bea510b75e9fa1e13081fcae.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000417_f8727_x3859_y1382_png.rf.ea0378237c4ecb01b31b2f6f87344eb5.jpg (deflated 20%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000953_f1591_x1524_y5020_png.rf.6995373412ad102c308d042d78bf4450.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000116_f5326_x2191_y3516_png.rf.965801e4838848a38b143da100fbbeaa.jpg (deflated 37%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000138_f10094_x1399_y3818_png.rf.cc1fabaa8a76ccbf3a22faa4f4319798.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000047_f7519_x4249_y2779_png.rf.3ea4be55fb4eb309df00ce6e2220a404.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000070_f10619_x1595_y5425_png.rf.56d5fa9436f08b840ca44a8b044713b7.jpg (deflated 22%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000759_f1593_x5444_y1867_png.rf.8da56aec2ba4b42d78c6895576cc5a5e.jpg (deflated 22%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000011_f10655_x29_y3330_png.rf.e3a551c8514efcf41fb7ad0e9f2b5b35.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000002_f2207_x3722_y484_png.rf.b558f6412284de546582d0e00b487b2a.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000181_f7142_x5893_y1556_png.rf.ae60c55621a86c32fab5cac011b5fd3c.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000910_f1488_x4541_y5378_png.rf.21dbd9c160b46c1fdffe4870b7f7647d.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000710_f8000_x983_y5430_png.rf.81943ff12c4a262ca5904308164e6a75.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000009_f11679_x2890_y753_png.rf.d944c835aec18fb5d0436fe2a2a73bdf.jpg (deflated 20%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000262_f1284_x5240_y1842_png.rf.aba854e14a9b813851080f2379372722.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000682_f11294_x3993_y3000_png.rf.48641867c1275334e7fd703eb957426e.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000598_f12004_x1377_y2753_png.rf.42fb42d0ee597c6d51dcce3fa8d3b04e.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000015_f452_x3420_y4278_png.rf.c7a43fa3eb99a6b81fbc0d5044d91b06.jpg (deflated 10%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000484_f8562_x1260_y2163_png.rf.c4b32dee1d7866363ba4c61338af87e6.jpg (deflated 27%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000060_f9017_x5774_y1129_png.rf.9a6c07543bee19aec5b1c9c970c29c57.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000539_f10719_x2013_y2897_png.rf.b5fcae86caf66277e87294ec241c3bbc.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000779_f7132_x2333_y3302_png.rf.3aba53ceb85a0aedbc123fbcecf8658c.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000434_f4667_x5366_y1173_png.rf.30f7c956d684d170538b6f2044b519f8.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000060_f1726_x3216_y3194_png.rf.2f063058fc52722e5b3d18558b5af907.jpg (deflated 9%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000025_f508_x4684_y2434_png.rf.7b1bbff918f73dfc2818622c50de4fb5.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000170_f98_x4767_y2513_png.rf.7122eec64e4bcffb7c30e3c9d31d20b2.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000250_f8431_x5073_y4419_png.rf.c55b61b04842603064be80283278d886.jpg (deflated 28%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000197_f2200_x4344_y677_png.rf.711ec06a521e7da9a55c86e8bc41a20d.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000844_f12328_x2090_y1838_png.rf.fadffa10b5f5289728eeb51b3b6c280c.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000286_f498_x5381_y4643_png.rf.caad9953ccb07983c43bfc92deed6966.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000144_f1341_x3694_y2732_png.rf.96e296836a35c81dd5cfa16e68761968.jpg (deflated 9%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000078_f12403_x2517_y3078_png.rf.3540fbaba300f38f9916c1c134d9dccc.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000310_f385_x3412_y5700_png.rf.4844fb92f33b2a407d4b1ff2e02d3268.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000610_f6203_x437_y2351_png.rf.d9b55e0ac4ae2eca1d5eff6fa6766158.jpg (deflated 27%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000646_f1413_x3167_y5122_png.rf.b18c21cd8ecb2eb0575a26323a138b86.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000509_f108_x4173_y814_png.rf.013fd85ae90949f251a541f7beea1901.jpg (deflated 20%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000077_f7332_x363_y2461_png.rf.b94f882ff304a93018466a68ac795bbe.jpg (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000986_f11345_x3444_y5948_png.rf.16b3a11fe272bcabea20001b6b528dad.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000196_f965_x1706_y5335_png.rf.0af625ca3dd321dd28388baeee943535.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000387_f9974_x5005_y784_png.rf.eb1b2e095d5234da817ee42e40f1d1f9.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000425_f7384_x5612_y2624_png.rf.11de354a66ded6dde8adad81b170a409.jpg (deflated 30%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000991_f4614_x4557_y253_png.rf.074d02e7c099db0db5728fd89896be16.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000013_f72_x5111_y5837_png.rf.b41869aa911110d672429dfc6ad654cf.jpg (deflated 7%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000014_f724_x711_y1860_png.rf.dd2c5bc56991d1eb70fb241855207ac4.jpg (deflated 27%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000443_f9070_x3054_y1068_png.rf.322dc09ecacdfbbb71975a8ce9a676b4.jpg (deflated 24%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000681_f2754_x189_y572_png.rf.fba4985335eb02e46ac60999faec1944.jpg (deflated 4%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000379_f484_x1169_y3921_png.rf.4ec7aeefa203d3216d2ed0ffcd05dbb1.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000806_f5081_x3342_y2485_png.rf.3ba89f15f0d1676fa0a3af70c82d6eb6.jpg (deflated 10%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000970_f12380_x4133_y3684_png.rf.e7008d640838c6fb162b7cd246a87ff8.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000485_f718_x3710_y4665_png.rf.e71bf22db70776eb1686cabf5c1e1d02.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000300_f4638_x215_y3417_png.rf.45df68934154a2da44598e334eb6c224.jpg (deflated 56%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/images/tile_000025_f9762_x509_y5020_png.rf.2a9de1eeb49b57c635ef58d1b20d586b.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/ (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000002_f2207_x3722_y484_png.rf.b558f6412284de546582d0e00b487b2a.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000262_f1284_x5240_y1842_png.rf.aba854e14a9b813851080f2379372722.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000025_f9762_x509_y5020_png.rf.2a9de1eeb49b57c635ef58d1b20d586b.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000953_f1591_x1524_y5020_png.rf.6995373412ad102c308d042d78bf4450.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000540_f2350_x3126_y1920_png.rf.a53ed397f0f4e1162cd072eb128d6591.txt (deflated 45%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000539_f10719_x2013_y2897_png.rf.b5fcae86caf66277e87294ec241c3bbc.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000986_f11345_x3444_y5948_png.rf.16b3a11fe272bcabea20001b6b528dad.txt (deflated 53%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000646_f1413_x3167_y5122_png.rf.b18c21cd8ecb2eb0575a26323a138b86.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000138_f10094_x1399_y3818_png.rf.cc1fabaa8a76ccbf3a22faa4f4319798.txt (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000798_f11448_x2566_y4674_png.rf.e7949b94852f4b4390d1790ec8cbf7ba.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000214_f395_x2192_y3127_png.rf.579c28d6ce50a7c533b479fe71ca6612.txt (deflated 53%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000011_f10655_x29_y3330_png.rf.e3a551c8514efcf41fb7ad0e9f2b5b35.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000473_f958_x5839_y3649_png.rf.33ad949c6adde124ec9659dc43ac48aa.txt (deflated 51%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000047_f7519_x4249_y2779_png.rf.3ea4be55fb4eb309df00ce6e2220a404.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000230_f276_x5855_y598_png.rf.e8fcdc046d436063ff606b41c2b57095.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000056_f326_x1467_y844_png.rf.f5fd0e8b15c9f365649b8b9e98c71751.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000417_f8727_x3859_y1382_png.rf.ea0378237c4ecb01b31b2f6f87344eb5.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000060_f1726_x3216_y3194_png.rf.2f063058fc52722e5b3d18558b5af907.txt (deflated 53%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000387_f9974_x5005_y784_png.rf.eb1b2e095d5234da817ee42e40f1d1f9.txt (deflated 38%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000286_f498_x5381_y4643_png.rf.caad9953ccb07983c43bfc92deed6966.txt (deflated 38%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000970_f12380_x4133_y3684_png.rf.e7008d640838c6fb162b7cd246a87ff8.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000070_f10619_x1595_y5425_png.rf.56d5fa9436f08b840ca44a8b044713b7.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000844_f12328_x2090_y1838_png.rf.fadffa10b5f5289728eeb51b3b6c280c.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000060_f9017_x5774_y1129_png.rf.9a6c07543bee19aec5b1c9c970c29c57.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000484_f8562_x1260_y2163_png.rf.c4b32dee1d7866363ba4c61338af87e6.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000310_f385_x3412_y5700_png.rf.4844fb92f33b2a407d4b1ff2e02d3268.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000910_f1488_x4541_y5378_png.rf.21dbd9c160b46c1fdffe4870b7f7647d.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000239_f2128_x4961_y5577_png.rf.34b6cd2fe8f672c481ce7e32df6ae97b.txt (deflated 51%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000197_f2200_x4344_y677_png.rf.711ec06a521e7da9a55c86e8bc41a20d.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000485_f718_x3710_y4665_png.rf.e71bf22db70776eb1686cabf5c1e1d02.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000008_f6763_x4192_y6025_png.rf.6a4b2a20c14030ba9ec9320094ce1e7d.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000300_f4638_x215_y3417_png.rf.45df68934154a2da44598e334eb6c224.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000196_f965_x1706_y5335_png.rf.0af625ca3dd321dd28388baeee943535.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000099_f7625_x3286_y5834_png.rf.bef33a448bd6e5bed977ccf86cf1b1ac.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000033_f8647_x4091_y980_png.rf.16887f5f86a538af6bcc5413a0804ba4.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000991_f4614_x4557_y253_png.rf.074d02e7c099db0db5728fd89896be16.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000173_f6211_x286_y583_png.rf.40a59f1d589582b1e3ffed85d881453c.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000434_f4667_x5366_y1173_png.rf.30f7c956d684d170538b6f2044b519f8.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000681_f2754_x189_y572_png.rf.fba4985335eb02e46ac60999faec1944.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000379_f484_x1169_y3921_png.rf.4ec7aeefa203d3216d2ed0ffcd05dbb1.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000031_f2212_x3325_y3684_png.rf.5d4bf6c57fb265e77cf479b9cfffc40a.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000443_f9070_x3054_y1068_png.rf.322dc09ecacdfbbb71975a8ce9a676b4.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000847_f11214_x4384_y1887_png.rf.92142fcd73cb1f26deac53af692d094b.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000509_f108_x4173_y814_png.rf.013fd85ae90949f251a541f7beea1901.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000425_f7384_x5612_y2624_png.rf.11de354a66ded6dde8adad81b170a409.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000009_f11679_x2890_y753_png.rf.d944c835aec18fb5d0436fe2a2a73bdf.txt (deflated 46%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000083_f2281_x1762_y2776_png.rf.b323285b75194011a7396dd9685249dd.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000015_f452_x3420_y4278_png.rf.c7a43fa3eb99a6b81fbc0d5044d91b06.txt (deflated 38%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000250_f8431_x5073_y4419_png.rf.c55b61b04842603064be80283278d886.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000014_f724_x711_y1860_png.rf.dd2c5bc56991d1eb70fb241855207ac4.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000506_f2653_x3003_y3487_png.rf.371bd6d81b709f97006b6aefdde520ee.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000116_f5326_x2191_y3516_png.rf.965801e4838848a38b143da100fbbeaa.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000313_f10813_x5153_y2380_png.rf.bc206ee4bea510b75e9fa1e13081fcae.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000021_f10668_x5448_y3734_png.rf.6b1ab307a682df5347f9a2cd54b28ba4.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000806_f5081_x3342_y2485_png.rf.3ba89f15f0d1676fa0a3af70c82d6eb6.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000610_f6203_x437_y2351_png.rf.d9b55e0ac4ae2eca1d5eff6fa6766158.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000013_f72_x5111_y5837_png.rf.b41869aa911110d672429dfc6ad654cf.txt (deflated 54%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000475_f5553_x132_y4257_png.rf.59208821fc0246e9ff1d9104d3e7b528.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000025_f508_x4684_y2434_png.rf.7b1bbff918f73dfc2818622c50de4fb5.txt (deflated 37%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000934_f2372_x2190_y2841_png.rf.e3b5ab96534d334df615f4cd32b23824.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000077_f7332_x363_y2461_png.rf.b94f882ff304a93018466a68ac795bbe.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000190_f12025_x605_y1929_png.rf.0153aa7a2193da85331152164274f99d.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000326_f1269_x4183_y1796_png.rf.64c2be30556e4e0d3a307728f7ebce8d.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000779_f7132_x2333_y3302_png.rf.3aba53ceb85a0aedbc123fbcecf8658c.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000345_f2123_x5321_y2556_png.rf.53713aed91d3c505b6534a8954b692de.txt (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000710_f8000_x983_y5430_png.rf.81943ff12c4a262ca5904308164e6a75.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000181_f7142_x5893_y1556_png.rf.ae60c55621a86c32fab5cac011b5fd3c.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000144_f1341_x3694_y2732_png.rf.96e296836a35c81dd5cfa16e68761968.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000078_f12403_x2517_y3078_png.rf.3540fbaba300f38f9916c1c134d9dccc.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000170_f98_x4767_y2513_png.rf.7122eec64e4bcffb7c30e3c9d31d20b2.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000598_f12004_x1377_y2753_png.rf.42fb42d0ee597c6d51dcce3fa8d3b04e.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000759_f1593_x5444_y1867_png.rf.8da56aec2ba4b42d78c6895576cc5a5e.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000058_f10535_x889_y665_png.rf.6eef0bd5d0248ac3d666b9ab3b26f094.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/valid/labels/tile_000682_f11294_x3993_y3000_png.rf.48641867c1275334e7fd703eb957426e.txt (deflated 54%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/ (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/ (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000064_f12710_x447_y2602_png.rf.7a5657eab6c369f945516782b64cec10.jpg (deflated 24%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000823_f9890_x2660_y222_png.rf.72588a2c28d083171127ac141606a11f.jpg (deflated 24%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000062_f9619_x2369_y3753_png.rf.87b27f939bd8119faf183f42d784cae0.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000929_f9358_x1132_y4299_png.rf.0afba542825c218752240d2c6b6964d6.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000172_f5126_x3360_y1182_png.rf.ab5b66768843d8d299f0cf51f6d54e3f.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000642_f6455_x4279_y603_png.rf.85e2e058329dae3c1df00a7db2f6b1d5.jpg (deflated 24%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000494_f789_x836_y3492_png.rf.fd929e7901436c0cd8fa129114b62388.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000004_f1369_x5603_y1459_png.rf.e6a3877c8acc26028e1b43715aeece40.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000530_f12928_x2418_y4278_png.rf.b71063911f0c40618dcdfcde5403789b.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000435_f6025_x3613_y1548_png.rf.304f63af1cfccb811ddd1522d4d68bca.jpg (deflated 27%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000229_f2006_x4263_y239_png.rf.7623b619a2d47f0fe3f9a3f941fbc9ed.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000032_f2386_x1977_y5866_png.rf.06e7c7ddcf413ca1e72b0c4eaf73c022.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000846_f3330_x311_y2686_png.rf.bf6bbbf0527d62a7e3f5e65d3d5b7306.jpg (deflated 25%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000197_f8850_x4066_y5477_png.rf.6da01473d39de08ef2742466ce09b468.jpg (deflated 27%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000088_f9328_x3540_y1476_png.rf.33f7b0cdaecc5c3aceff6fd16bd77fff.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000196_f202_x3537_y1538_png.rf.a103ba9885a85631591d1128df81cc66.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000590_f3560_x3155_y4368_png.rf.35ab4dbad62e54b613fa9ba88817e8c1.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000332_f941_x2256_y3574_png.rf.82467c3f0a58bef67c2276aebb6b508d.jpg (deflated 11%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000252_f2446_x1876_y5005_png.rf.32057f11e22322bcca738cdfb8ae6363.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000458_f866_x748_y4379_png.rf.78146c41c1a1dd7bbda9322abb747c1e.jpg (deflated 22%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000273_f1056_x2735_y5253_png.rf.aa32b89db214b7056148fab610e8367f.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000256_f8500_x316_y4227_png.rf.25db104c11015f8c7899f5e73ba420ae.jpg (deflated 29%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000051_f8340_x3968_y1121_png.rf.4aa279051dd57409312cef6246b4cdaa.jpg (deflated 24%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000497_f2643_x4111_y2549_png.rf.a8d729cd7cbb1f2fba2a40ae9c81ebeb.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000774_f6036_x2817_y5872_png.rf.e5687d02c615e748300ba7c128ed1025.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000046_f3644_x4805_y4182_png.rf.c63129ec02b0d08beb0758dce8c515d0.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000064_f1818_x3529_y1844_png.rf.e0cdd3987c5c409efec7e42c77e6e2ba.jpg (deflated 11%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000134_f471_x2888_y5164_png.rf.61e547fb87f6bdf133ea4f7ce2d2ef8b.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000431_f6791_x3433_y29_png.rf.ebe039aef4c630e93086cdf2ca9452fa.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000473_f2626_x2338_y3508_png.rf.f20c386d5982aef54433a891d394dffb.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000263_f2579_x73_y1774_png.rf.d5b2f25b32937c17ff2cb1bb18cc71a1.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000188_f30_x5030_y2606_png.rf.82576fc0dff909369299b003c1435f1a.jpg (deflated 85%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000074_f3192_x2065_y5695_png.rf.a9e5b30057097e5984bd2e4a5eb51562.jpg (deflated 22%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000442_f4625_x3637_y1300_png.rf.d5caca73f36f85b76ddc46323e6c8ca2.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000492_f795_x1925_y5935_png.rf.20674fd8d4c777ba9023c09c0e910053.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000189_f2225_x4524_y1198_png.rf.9e1dcbbbe7780bd707afe5d8db41c690.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000416_f309_x363_y1845_png.rf.c1801743d35454bba2265fc5a0c54bcf.jpg (deflated 22%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000815_f2864_x3814_y1048_png.rf.5231d78dc4859e20a692d76968387f3d.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000028_f127_x1699_y5861_png.rf.1c2038e2797680865a20bfd75455fcd7.jpg (deflated 17%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000227_f3922_x3796_y267_png.rf.91437801f2843d1749cfd03976cd79c0.jpg (deflated 50%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000128_f5523_x4582_y3589_png.rf.50ba10438a603da2d5be685048360ebe.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000787_f2601_x3806_y6050_png.rf.0cb77b7f1e07d3574fdf44158a7ba23d.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000185_f5118_x1331_y4884_png.rf.cdb5dfd6e0828706fd64e38098dd63cf.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000235_f4588_x1260_y1702_png.rf.9c8edb73bf7c1d930a712f28eef1bae5.jpg (deflated 20%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000051_f9097_x4600_y3312_png.rf.f623c22ee446fbbae556e70f74da335b.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000444_f8172_x341_y2657_png.rf.61abbd3ddc801a9c4ceb09c4cb60db3b.jpg (deflated 37%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000130_f7442_x1591_y2878_png.rf.1a5f077fa9938b3f7a82ede2d3f429dc.jpg (deflated 26%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000185_f5943_x2513_y1457_png.rf.105aa9149cf63f53a6d51fd30ae88e98.jpg (deflated 37%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000124_f11806_x4069_y5263_png.rf.2bbc6ea2a0793fb8e05e74cb2e322541.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000182_f1941_x4369_y3351_png.rf.83f7286af3c2139106755b8bb1370280.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000061_f2185_x4242_y4583_png.rf.9b52c732dcdae597c3f45d42433d6f64.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000141_f9050_x1318_y5908_png.rf.f0f6133bb4cd57944057a7c4cfa5b67f.jpg (deflated 15%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000351_f10431_x4847_y5135_png.rf.618486eb20d21b5ede0be70457f0ae5f.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000998_f9203_x3037_y595_png.rf.66ba706885d5cef94839f0e6584e563c.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000518_f3671_x3408_y2048_png.rf.1e6c27982e5b0a00aca0800c849b0549.jpg (deflated 12%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000753_f2364_x3595_y1824_png.rf.2222156913225f78f16cb84c384adc18.jpg (deflated 10%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000093_f3605_x1609_y508_png.rf.4847aec5e1726c14fa25e27fc1c7f034.jpg (deflated 23%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000112_f5392_x4194_y5556_png.rf.df8573fcb4209e9cb7db3cb82173491e.jpg (deflated 46%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000482_f2150_x4659_y5243_png.rf.5b4a0e1a804cd7592651e01d7bae732d.jpg (deflated 20%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000285_f1199_x5615_y4822_png.rf.588d0a988ea17f5f1afcfc1cd686558e.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000098_f4842_x5825_y4291_png.rf.a10afd1ca4e748611a2f0f833775c8b1.jpg (deflated 44%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000035_f1468_x5000_y4928_png.rf.4d2fac25aeab61298899994ea2c62732.jpg (deflated 20%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000005_f690_x1057_y5008_png.rf.63dde5086af8e744c1ccf60902f2c093.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000293_f4901_x1289_y5228_png.rf.2834c8160823a2177b9c10b35c74444e.jpg (deflated 22%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000987_f6332_x713_y4036_png.rf.d109c3c3560b45aec8682e6b80c1a844.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000084_f9889_x3170_y5903_png.rf.c02c07b3a657c20f54797ddbb3932d7b.jpg (deflated 22%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000877_f2025_x3681_y4177_png.rf.204e52915ecd8da7c9c6f9693ba5c579.jpg (deflated 11%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000256_f7659_x5340_y2011_png.rf.816d596d9f5ddf502a87e572babfecbf.jpg (deflated 35%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000219_f544_x5023_y5386_png.rf.7a6f08b3deac1487066da4be1eb7738b.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000619_f5459_x848_y2882_png.rf.04590e3568f6543a91938258578ed5e7.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000164_f1041_x5604_y3293_png.rf.33cf3e651a207f5dd8aa7a9fbe3672b4.jpg (deflated 21%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000349_f11173_x4049_y4126_png.rf.406b956dfc9f87da758fedae3064585a.jpg (deflated 5%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000404_f1349_x2183_y5825_png.rf.66236df113992ab4524c88a9db33ec34.jpg (deflated 22%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000260_f9280_x975_y1070_png.rf.2e83c5e586ee650ed9ef3410a84d3c29.jpg (deflated 24%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000143_f2261_x2139_y3015_png.rf.e74f745fa0e234488142807255f32bd8.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000000_f1496_x954_y5203_png.rf.7b2a5b65c09a198b729071d270c565a1.jpg (deflated 24%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000064_f713_x2041_y2555_png.rf.a0a8d1d1f3bfc9736875674c69be0e48.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000297_f693_x4267_y4339_png.rf.d3f9f3637c9df016d4abfdfc22e8d2ab.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000677_f2947_x649_y3297_png.rf.34cd2220e91958a86b551d6be8c7aa09.jpg (deflated 19%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000059_f10419_x4339_y1161_png.rf.e6dc8a2250c625c69880111096c7a884.jpg (deflated 22%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000295_f12844_x4711_y3699_png.rf.f58b4dd314d0c38bbf0cdec276784ed5.jpg (deflated 14%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000701_f1150_x448_y4999_png.rf.822e29ee6056cf05158e5a4078c3f273.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000551_f9016_x1601_y5146_png.rf.2768ff34f72a31c3267c3273fed9a5b4.jpg (deflated 20%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000515_f3528_x4769_y5175_png.rf.05dcbd197b4e48045851cd47b6ee4350.jpg (deflated 22%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000183_f10426_x813_y581_png.rf.fbc3a9d0bacb2f7240e4646815e882f0.jpg (deflated 18%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000453_f9505_x554_y3610_png.rf.3f59194d26bc2fa93cd27f2e5aec2e45.jpg (deflated 24%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000466_f7295_x3895_y4268_png.rf.d394c13869b81e9825833d9980114b40.jpg (deflated 13%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000977_f10368_x5611_y3941_png.rf.ba652e64dec5b711d636bff880d3b25a.jpg (deflated 23%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000437_f7512_x256_y3088_png.rf.801822d7aed73a3418a8143e4326255d.jpg (deflated 25%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000034_f5992_x1397_y4094_png.rf.190ee7bffed798ed88dfcc8610fcc85e.jpg (deflated 16%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/images/tile_000065_f11628_x1559_y3435_png.rf.79594302e8439aa856ca3ca4c6f64577.jpg (deflated 16%)
# ...
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000387_f1759_x3754_y5527_png.rf.b68e6e37a0b8b5cc58258569aa92d775.txt (deflated 38%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000053_f6471_x4111_y1745_png.rf.66b07a6a6b35e547c03f315e9e92351a.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000065_f11628_x1559_y3435_png.rf.79594302e8439aa856ca3ca4c6f64577.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000185_f5118_x1331_y4884_png.rf.cdb5dfd6e0828706fd64e38098dd63cf.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000293_f4901_x1289_y5228_png.rf.2834c8160823a2177b9c10b35c74444e.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000087_f1021_x1641_y5184_png.rf.237b82412a23087786738136b7ec64da.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000908_f98_x4851_y3118_png.rf.2bd72be247dbaa4bd844e204f9c7322b.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000515_f3528_x4769_y5175_png.rf.05dcbd197b4e48045851cd47b6ee4350.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000068_f9113_x4086_y5281_png.rf.5b1afcf9b2f84e4eb7c8a36c8bdd4a01.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000977_f10368_x5611_y3941_png.rf.ba652e64dec5b711d636bff880d3b25a.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000518_f3671_x3408_y2048_png.rf.1e6c27982e5b0a00aca0800c849b0549.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000551_f9016_x1601_y5146_png.rf.2768ff34f72a31c3267c3273fed9a5b4.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000437_f7512_x256_y3088_png.rf.801822d7aed73a3418a8143e4326255d.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000183_f10426_x813_y581_png.rf.fbc3a9d0bacb2f7240e4646815e882f0.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000851_f1056_x3465_y4522_png.rf.3875fd97f1b1b154a0e9d6ce74ca3f31.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000469_f105_x5934_y2468_png.rf.32b2c0fb5f3502b6732f6e173909d9f9.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000446_f708_x3264_y5419_png.rf.99e62033d802e7d28eab17eb40922680.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000464_f1521_x2184_y2930_png.rf.037856f891c4583c74a886eafe0a5ab2.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000219_f544_x5023_y5386_png.rf.7a6f08b3deac1487066da4be1eb7738b.txt (deflated 38%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000297_f693_x4267_y4339_png.rf.d3f9f3637c9df016d4abfdfc22e8d2ab.txt (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000148_f949_x4220_y2806_png.rf.8c3b16a5954d84d271983d8f24b9ca91.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000154_f2471_x1710_y5235_png.rf.183b6095092892a198a6e94cbe17abe5.txt (deflated 51%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000374_f1006_x2809_y3586_png.rf.d8731fb38bd32ec768419b5bfe65e106.txt (deflated 52%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000228_f134_x780_y2312_png.rf.0bd9ff2d74b28d89a05efb749e1a0bb7.txt (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000155_f11275_x5606_y4875_png.rf.d85d4028e2568edea7ec0ea045c0ccc8.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000282_f8038_x5804_y2846_png.rf.1a501658381c2478824f4cf2b66dfeb8.txt (deflated 38%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000125_f897_x818_y2844_png.rf.7b29c8087e01a0a082dc2e26e5d54e50.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000051_f252_x3217_y2858_png.rf.7263c796ab5b112aff73310700c8145d.txt (deflated 37%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000180_f2497_x5708_y3706_png.rf.bbaa0dc8fc508447f6692cb2df3b784c.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000317_f1558_x4866_y3592_png.rf.e5e8e832b74415759dc8aa1eb9a7ae43.txt (deflated 44%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000100_f1485_x3413_y3239_png.rf.bd02650ef5b2a32b97ef97544b6bae4e.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000196_f11906_x4939_y1914_png.rf.23022eb4bb5239d5215eb0da352503c6.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000377_f5293_x2693_y5102_png.rf.89240b4ae991f74ccce06bd042cc9476.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000124_f1747_x1906_y2633_png.rf.6c40561356177d50058df42d82bdb616.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000265_f8126_x3998_y1695_png.rf.77589f475fea5e4e857e99d78a3adb87.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000222_f8108_x3258_y3865_png.rf.35aaee2b7788bbe088335e3d57d953bc.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000325_f6927_x3033_y2438_png.rf.7968ac05e660e5411e01e65829303807.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000193_f11816_x2685_y3924_png.rf.f1df5fbbb457cb049b037844a13dc57b.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000856_f9318_x4_y1574_png.rf.4d3fa74c4e3a0f16a7a01942ad3c6f7e.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000143_f2261_x2139_y3015_png.rf.e74f745fa0e234488142807255f32bd8.txt (deflated 45%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000442_f4625_x3637_y1300_png.rf.d5caca73f36f85b76ddc46323e6c8ca2.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000217_f12751_x2710_y3739_png.rf.7093d32a61a5a68cdcfbce0b860f3da5.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000169_f1244_x1142_y2482_png.rf.ea6daa4ddd8e1931ad2bdb3051b61534.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000498_f5788_x124_y2208_png.rf.9c57f0323e01b124b16ea33879029cca.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000865_f10122_x4626_y3660_png.rf.ea46fee3a2dd230f6da6d89bec4655de.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000558_f8160_x3373_y4394_png.rf.13b2b5a2a1e25a8c2e401de9dfd14fc7.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000375_f3270_x5404_y381_png.rf.7365c8e27feee9feba4bb47aef92e564.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000134_f471_x2888_y5164_png.rf.61e547fb87f6bdf133ea4f7ce2d2ef8b.txt (deflated 38%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000591_f1365_x3339_y3522_png.rf.8f00bfd6fd4af206d6970f55cb085d49.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000099_f5435_x562_y2578_png.rf.d81e7557da57e9f7a13aed45db845ef0.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000111_f11347_x936_y4880_png.rf.383ca10da8c9590bc86e30b53b396300.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000352_f1850_x3692_y257_png.rf.0e95dde19d6cd96d51fc6c17d2da53c4.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000303_f9926_x3185_y1910_png.rf.87479aa25d0a561713b6f8ad0a85bb19.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000728_f6526_x4139_y5202_png.rf.60c3b96d5640ac966d016786e0e6d463.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000112_f8588_x4446_y1190_png.rf.4373e7cca0ed1332986e1150f2f9606d.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000052_f1861_x3288_y5818_png.rf.6792314fb0f9051661ee79f7cdb86bcc.txt (deflated 50%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000049_f4983_x5665_y2751_png.rf.db625c55888a3811e385a258724f99f1.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000313_f9346_x5729_y652_png.rf.b1d2f17cfd07b0f7d9eac2ace1e25ef9.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000059_f6410_x5921_y2303_png.rf.013eeddd6982b2c9686b974c27719fa3.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000132_f11566_x1845_y3136_png.rf.f66e3b37e648fb2aa8c397a2a453265d.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000823_f9890_x2660_y222_png.rf.72588a2c28d083171127ac141606a11f.txt (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000494_f789_x836_y3492_png.rf.fd929e7901436c0cd8fa129114b62388.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000074_f3192_x2065_y5695_png.rf.a9e5b30057097e5984bd2e4a5eb51562.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000070_f1455_x4085_y4830_png.rf.6d75e20154e525baf0bc917894233f32.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000492_f795_x1925_y5935_png.rf.20674fd8d4c777ba9023c09c0e910053.txt (deflated 44%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000263_f2579_x73_y1774_png.rf.d5b2f25b32937c17ff2cb1bb18cc71a1.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000189_f11484_x2056_y3252_png.rf.7f26ad4abab0b02785d4a1337b036cd1.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000036_f12532_x4956_y1332_png.rf.baa62351d9efe3acf398b5e657b61ecd.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000032_f2386_x1977_y5866_png.rf.06e7c7ddcf413ca1e72b0c4eaf73c022.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000046_f3644_x4805_y4182_png.rf.c63129ec02b0d08beb0758dce8c515d0.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000196_f202_x3537_y1538_png.rf.a103ba9885a85631591d1128df81cc66.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000162_f439_x5760_y5569_png.rf.80f6b51699ca1889b9b2b3dcb750b369.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000458_f866_x748_y4379_png.rf.78146c41c1a1dd7bbda9322abb747c1e.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000933_f12980_x1536_y2045_png.rf.e2b879332459629bbbc403df0d158ef9.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000008_f7701_x1039_y4797_png.rf.0fe598d35fe6b9fdcbd8b11983010ad2.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000416_f309_x363_y1845_png.rf.c1801743d35454bba2265fc5a0c54bcf.txt (deflated 38%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000071_f11843_x973_y5629_png.rf.316a69fe7bd5bce27b6d0b38232270f7.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000765_f8462_x965_y3701_png.rf.2d922b21935ae05e484b0bef77051820.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000064_f1818_x3529_y1844_png.rf.e0cdd3987c5c409efec7e42c77e6e2ba.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000252_f2446_x1876_y5005_png.rf.32057f11e22322bcca738cdfb8ae6363.txt (deflated 38%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000062_f9619_x2369_y3753_png.rf.87b27f939bd8119faf183f42d784cae0.txt (deflated 39%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000229_f2006_x4263_y239_png.rf.7623b619a2d47f0fe3f9a3f941fbc9ed.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000642_f6455_x4279_y603_png.rf.85e2e058329dae3c1df00a7db2f6b1d5.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000877_f2025_x3681_y4177_png.rf.204e52915ecd8da7c9c6f9693ba5c579.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000109_f7726_x861_y1964_png.rf.aa1d73029c606cca4770be4c42bc4be0.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000774_f6036_x2817_y5872_png.rf.e5687d02c615e748300ba7c128ed1025.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000474_f12044_x5257_y5440_png.rf.7a81d03977176a94d2f5223500d70c47.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000372_f12906_x5070_y5753_png.rf.060df6e79ee8ca7265e127417930d621.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000004_f1369_x5603_y1459_png.rf.e6a3877c8acc26028e1b43715aeece40.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000846_f3330_x311_y2686_png.rf.bf6bbbf0527d62a7e3f5e65d3d5b7306.txt (deflated 36%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000088_f9328_x3540_y1476_png.rf.33f7b0cdaecc5c3aceff6fd16bd77fff.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000890_f3006_x5134_y2930_png.rf.e6f4149da4d1cf56700e6c8d053ba3b7.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000188_f30_x5030_y2606_png.rf.82576fc0dff909369299b003c1435f1a.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000051_f8340_x3968_y1121_png.rf.4aa279051dd57409312cef6246b4cdaa.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000530_f12928_x2418_y4278_png.rf.b71063911f0c40618dcdfcde5403789b.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000064_f12710_x447_y2602_png.rf.7a5657eab6c369f945516782b64cec10.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000929_f9358_x1132_y4299_png.rf.0afba542825c218752240d2c6b6964d6.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000431_f6791_x3433_y29_png.rf.ebe039aef4c630e93086cdf2ca9452fa.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000197_f8850_x4066_y5477_png.rf.6da01473d39de08ef2742466ce09b468.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000065_f5816_x2345_y2106_png.rf.900c7e8581cb872c22de31a0ee1900a6.txt (deflated 40%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000497_f2643_x4111_y2549_png.rf.a8d729cd7cbb1f2fba2a40ae9c81ebeb.txt (deflated 42%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000787_f2601_x3806_y6050_png.rf.0cb77b7f1e07d3574fdf44158a7ba23d.txt (deflated 44%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000435_f6025_x3613_y1548_png.rf.304f63af1cfccb811ddd1522d4d68bca.txt (deflated 43%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000022_f2571_x2164_y2530_png.rf.a3de91bd8f0ccc0539b36f441a73ec80.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000189_f2225_x4524_y1198_png.rf.9e1dcbbbe7780bd707afe5d8db41c690.txt (stored 0%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000332_f941_x2256_y3574_png.rf.82467c3f0a58bef67c2276aebb6b508d.txt (deflated 41%)
#   adding: content/drive/MyDrive/Keypoint_reduced/train/labels/tile_000256_f8500_x316_y4227_png.rf.25db104c11015f8c7899f5e73ba420ae.txt (stored 0%)

# %% [markdown]
# # Load data
#
# Use the interactive widget below to choose your dataset source. You can select one of:
#
# ### 1. Roboflow
# - Paste your **Roboflow API key**, **workspace**, **project**, **version**, and **export format** (e.g., `yolov11`).
# - Tip: Usually copied from **Roboflow → Export → Show download code** on your project page.
#
# ### 2. Google Drive link (shared `.zip`)
# - Copy the **Drive share URL** of your `.zip` (set sharing to **Anyone with the link**).
# - Paste it into the widget and confirm to download and extract.
#
# ### 3. Example dataset from GitHub (Hexbugs)
# - Select **Hexbugs** to load a small, YOLO-formatted example dataset for quick testing.

# %%
# Select and fetch dataset via interactive UI


# workspace_root = Path('/content/drive/MyDrive/Colab Notebooks')
workspace_root = Path('/content/train-custom-YOLO-Colab/')
if workspace_root.exists() and str(workspace_root) not in sys.path:
    sys.path.append(str(workspace_root))
if str(Path.cwd()) not in sys.path:
    sys.path.append(str(Path.cwd()))

from utils.datasets import launch_dataset_selector
workspace_dataset_root = Path('/content/datasets')
launch_dataset_selector(globals(), dataset_root=workspace_dataset_root)
# Out:
# VBox(children=(Dropdown(description='Source:', options=(('Roboflow snippet', 'roboflow'), ('Google Drive link'…

# %%
# workspace_root = Path('/content/drive/MyDrive/Colab Notebooks')
# if workspace_root.exists() and str(workspace_root) not in sys.path:
#     sys.path.append(str(workspace_root))
# if str(Path.cwd()) not in sys.path:
#     sys.path.append(str(Path.cwd()))

from utils.prep import (
    Data,
    auto_select_allowed_ids,
    build_collapse_map,
    build_new_class_ids_from_yaml,
    check_dataset,
    count_labels,
    filter_labels,
    make_data_yaml,
    prepare_yolo_dataset,
    simplify_labels,
    summarize_classes,
    tile_with_yolo_tiler,
)

dataset = Data('/content/datasets/', name)

assert os.path.exists(dataset.location + name + '/train')

dataset.location

# %% [markdown]
# ### Optional: Rename your annotated labels — What this cell does
#
# - **Purpose:** Collapse/rename your original classes into broader groups (e.g., many ray species → `sting_ray`, many shark types → `shark`) before training.
#
# - **Example**
# If you have a training dataset with 4 annotated species (e.g. 'cowtail_sting_ray','pink_stingray','blacktip_reef_shark','whitetip_reef_shark) but only want to train a simple model with two classes such as 'shark' and 'ray', then you can rename your classes to reduce the number of labels. In this case, depending on the class number that was assigned to your species on your annotations dataset (e.g. 0 is 'cowtail_sting_ray', 1 is 'pink_stingray',2 is 'blacktip_reef_shark',3 is 'whitetip_reef_shark), then you can remap as in the example below.
#
# - **`collapse_map`**
#   Maps **original class IDs** → **new group names**.
#   - Only IDs listed here are **kept**.
#   - Commented-out lines are **ignored** (those classes will be dropped).
#
#
# - **`allowed_ids`**
#   Set of original IDs you’re keeping (i.e., the keys of `collapse_map`). Used to **filter** annotations.
#
# - **`new_class_ids`**
#   Assigns **final numeric IDs** to the new groups (e.g., `shark:0`, `sting_ray:1`). These become your **contiguous class indices** used by YOLO.
#
# - **Outcome**
#   After your relabel step runs, annotations are remapped so that all sharks share ID `0`, all sting rays share ID `1`, and unlisted classes are dropped.
#
# - **Don’t forget**
#   Update your `data.yaml` to match the **new class list and order** (e.g., `names: ['shark','sting_ray']`).

# %%
# ----------------------------------------------
# 🔁 Step 1: Collapse or remap class labels (optional)
# ----------------------------------------------
# OPTIONAL — Use this to change how labels are grouped, e.g. merging multiple shark types into one class.

# Collapse original class IDs into broader categories
collapse_map = {
    0: 'sting_ray',    # cowtail_sting_ray
    1: 'sting_ray',    # pink_Stingray
    2: 'shark',        # blacktip_reef_shark
    3: 'shark',        # whitetip_reef_shark

}

allowed_ids = set(collapse_map.keys())

# Assign new numeric IDs to the collapsed categories
new_class_ids = {
    'shark': 0,
    'sting_ray': 1,
}

# %% [markdown]
# # Auto-select classes, remap IDs, and create a dataset
#
# ## What this cell does
# - **Auto-selects** classes that meet minimum data thresholds.
# - **Builds** a contiguous ID mapping (old → new).
# - **Prepares** a filtered, optionally rebalanced **train/val/test** split.
#
# ## Steps
#
# ### 1) Point to your dataset
# - `dataset_root = "/content/datasets/" + name` — the dataset folder chosen via the widget.
#
# ### 2) Auto-select viable classes
# - `auto_select_allowed_ids(dataset_root, min_instances=40, min_files=10)` returns:
#   - `allowed_ids`: original class IDs that pass thresholds.
#   - `instance_counts`: total labeled objects per class.
#   - `file_counts`: images containing each class.
# - Tune thresholds to your data size:
#   - `min_instances=40` (min total objects per class).
#   - `min_files=10` (min images per class; set `None` to ignore).
#
# ### 3) Build a compact remap
# - If `allowed_ids` is non-empty:
#   - `collapse_map = build_collapse_map(allowed_ids)` → e.g. `{3:0, 4:1, 7:2}`.
#   - `new_class_ids = sorted(set(collapse_map.values()))` → e.g. `[0, 1, 2]`.
# - Else: `collapse_map = None`, `new_class_ids = None` (skips remap).
#
# ### 4) Prepare the filtered dataset
# - `prepare_yolo_dataset(...)` runs with:
#   - `out_dir = dataset_root + "-filtered_split"` — output folder.
#   - `do_change_labels=True` + `collapse_map/new_class_ids` — apply remap to contiguous IDs.
#   - `allowed_ids=...`, `drop_others=True` — keep only chosen classes; drop the rest.
#   - `prune_empty_fraction=0.9` — remove up to **90%** of empty images (keeps ~10% negatives).
#   - `do_tile=False` — skip tiling in this pass.
#   - `do_rebalance=True` — mitigate class imbalance across splits.
#   - `split=(0.7, 0.2, 0.1)` — train/val/test ratios.
#   - `remove_test=False` — keep a test split.
#
# ## Output
# - A cleaned dataset at `...-filtered_split/` with:
#   - `train/`, `val/`, `test/` (images/labels),
#   - labels remapped to contiguous IDs,
#   - and an updated `data.yaml` compatible with YOLO.
#
# ## Notes
# - If `allowed_ids` is empty, relax `min_instances`/`min_files` or inspect class distribution.
# - Keeping a small fraction of negatives (`prune_empty_fraction`) usually improves generalization.

# %%
dataset_root = "/content/datasets/" + name           # or before splitting

allowed_ids, instance_counts, file_counts = auto_select_allowed_ids(
    dataset_root,
    min_instances=40,   # tune these to your dataset size
    min_files=10        # optional; set None to ignore
)

# 2) Build the class remapping (old → new contiguous ids)
if allowed_ids:
    collapse_map = build_collapse_map(allowed_ids)          # e.g. {3:0, 4:1, 7:2}
    new_class_ids = sorted(set(collapse_map.values()))      # e.g. [0,1,2]
else:
    collapse_map, new_class_ids = None, None

# 2) If you like the selection, run your prep with filtering only (no remap)
if allowed_ids:
    prepare_yolo_dataset(
        dataset_path=dataset_root,
        out_dir=dataset_root + "-filtered_split",
        do_change_labels=True,
        allowed_ids=allowed_ids,
        collapse_map=collapse_map,      # ← now active
        new_class_ids=new_class_ids,    # ← now active
        drop_others=True,               # drop unwanted ids
        prune_empty_fraction=0.2,
        do_tile=False,
        do_rebalance=True,
        split=(0.7, 0.2, 0.1),
        remove_test=False,
    )

# %% [markdown]
# ### Check number of labels per class

# %%
### Check here for each folder in the newsly created dataset '-filtered_split' how many labels per class we have
out_dir = '/content/datasets/' + name + '-filtered_split'  # e.g., the same `out_dir` you passed to prepare_yolo_dataset
check_dataset(out_dir)

# %% [markdown]
# ## Optional: crete a new yaml file
# If you didn't change labels you can directly copy the yaml file from the original folder to the rebalanced_data folder

# %%
make_yaml = True      # set True to generate a new YAML
copy_yaml = False     # keep False to avoid overwriting

base_dir = "/content/datasets/"           # root folder

src_yaml = os.path.join(base_dir, name, 'data.yaml')
dst_yaml = os.path.join(out_dir, 'data.yaml')

if make_yaml:
    new_class_ids = build_new_class_ids_from_yaml(
        src_yaml=src_yaml,
        allowed_ids=allowed_ids,
        collapse_map=collapse_map,
    )
    yaml_path = make_data_yaml(
        dataset_root=out_dir,
        new_class_ids=new_class_ids,
        has_test=None,  # auto-detect from folder existence
    )
    print('✅ data.yaml written to:', yaml_path)
elif copy_yaml:
    if os.path.exists(src_yaml):
        shutil.copy2(src_yaml, dst_yaml)
        print(f'✅ Copied data.yaml from {src_yaml} → {dst_yaml}')
    else:
        print(f'❌ Source data.yaml not found at {src_yaml}')

# %% [markdown]
# ### Optional: Create a zip folder with the new dataset to dowload it

# %%
make_zip = True                 # set to False to skip zipping

# === PATHS ===
folder = os.path.join(base_dir, f"{name}-filtered_split")
zip_path = os.path.join(base_dir, f"{name}-filtered_split.zip")

# === CONDITIONAL ZIP ===
if make_zip:
    if os.path.exists(folder):
        if not os.path.exists(zip_path):
            # !zip -r -q "{zip_path}" "{folder}"
            print(f"✅ Zipped: {zip_path}")
        else:
            print(f"⚠️ Zip file already exists: {zip_path}")
    else:
        print(f"❌ Folder not found: {folder}")
else:
    print("⏭️ Skipping ZIP creation (make_zip=False)")

# %% [markdown]
# ### Define output path

# %%
### Change path to your folder
REMOTE_URL = "/content/drive/MyDrive/models/" + name
HOME = "/content/datasets/"

# Change to HOME directory
# %cd {HOME}

# Import os and create the folder if it doesn't exist
import os

if not os.path.exists(REMOTE_URL):
    os.makedirs(REMOTE_URL)
    print(f"Directory '{REMOTE_URL}' created.")
else:
    print(f"Directory '{REMOTE_URL}' already exists.")

# %% [markdown]
# # Training: Parameters

# %%
# Change to home directory
# %cd {HOME}

# ---- User-defined Settings ----
resolution = 1080                # Image resolution for training
epochs = 300                     # Number of training epochs
batch_size = 6                   # Batch size
base_model = "yolo26s"         # Choose model variant. Options: "yolo11n-pose", "yolo11n-seg", "yolo11n" etc.


# ---- Auto-detect task type ----
if "-seg" in base_model:
    task = "segment"
elif "-pose" in base_model:
    task = "pose"
else:
    task = "detect"

# ---- 🔧 Training Settings ----
common_settings = {
    "translate": 0.05,       # Maximum image translation as data augmentation (in % of image size)
    "mixup": 0.1,          # MixUp blending factor for image mixing (usually low for object detection)
    "copy_paste": 0.3,      # Probability of using Copy-Paste augmentation (object pasting)
    "scale": 0.3,           # Random scaling of images for augmentation
    "mosaic": 0.5,             # Enable Mosaic augmentation (combines 4 images into 1)
    "close_mosaic": 10,      # Number of epochs before disabling mosaic for better fine-tuning
    "line_width": 1,         # Line width for label visualization
    "nms": True,             # Apply Non-Maximum Suppression during inference
    "plots": True,           # Save training plots (loss, mAP, etc.)
    "cache": "disk",         # Caching mode: "disk" to speed up I/O
    "single_cls": False,     # If True, treat all objects as one class (for class-agnostic detection)
    "amp": True,             # Enable automatic mixed precision (reduces memory, speeds up training)
    "augment": True,        # If True, applies augmentation at inference time
    "workers": 16,            # Number of dataloader workers (adjust depending on your CPU)
    "multi_scale": False,
    "hsv_h": 0.015,
    "hsv_s": 0.5,
    "hsv_v": 0.4

}


# Modify task-specific augmentations
if task == "detect":
    common_settings.update({
        "degrees": 10,       # Allow full rotation
        "flipud": 0.0,       # Vertical flip probability
        "fliplr": 0.0        # Horizontal flip probability
    })
else:
    common_settings.update({
        "degrees": 0,         # No rotation for pose/seg
        "flipud": 0.0,
        "fliplr": 0.0
    })

# Print CLI training parameters
parms = " ".join([f"{k}={v}" for k, v in common_settings.items()])
print("🔧 Training params:", parms)

# ---- 🗂️ Model Output Naming ----
from datetime import datetime
now = datetime.now()
date_string = now.strftime("%Y-%m-%d-%H") + "_" + dataset.name.replace(" ", "-") + "-" + str(dataset.version)

project = f"{resolution}-{base_model}"
if common_settings["mosaic"] > 0:
    project += "-mosaic"

# if sharkcam:
#     project += "-sharkcam"  # Add logic if needed

# ---- 🧠 Model Weights Source ----
model = base_model  # or path to a pretrained model
print(f"🧪 resolution={resolution} | project={project} | date_string={date_string}")
print(f"📦 model={model} | base_model={base_model} | task={task}")

# ---- 🔒 Safety Check ----
import os
assert model == base_model or os.path.exists(model + ".pt"), f"Model path not found: {model}.pt"

# %% [markdown]
# # Training: Run Command

# %%
    # Change to your working directory
# %cd {HOME}

# ---- Launch YOLO training ----
yolo_cmd = f"""
yolo task={task} \
     mode=train \
     resume=False \
     model={model}.pt \
     data={out_dir}/data.yaml \
     device=0 \
     name={date_string} \
     project={project} \
     epochs={epochs} \
     imgsz={resolution} \
     batch={batch_size} \
     patience=0 \
     visualize=True \
     {parms}
"""

# ▶️ Run the command
# !{yolo_cmd}

# %% [markdown]
# #5) Locate last trained model

# %%
# Change to the working directory
# %cd {HOME}

runs_root = f"{dataset.location}/runs/{task}/{project}"

# List all subdirectories in the project folder
all_subdirs = [os.path.join(runs_root, d) for d in os.listdir(runs_root)]
all_subdirs = [d for d in all_subdirs if os.path.isdir(d)]

# Keep only those that contain a trained model
all_subdirs = [d for d in all_subdirs if os.path.exists(os.path.join(d, "weights", "last.pt"))]


# Get the most recently modified subdirectory
latest_subdir = max(all_subdirs, key=os.path.getmtime)

# Construct the full path to the latest run
# full_path = HOME + "/" + latest_subdir

print(project)
print(latest_subdir)
# print(full_path)

# Save training parameters to a parms.txt
# !echo "{parms}" > {latest_subdir}/parms.txt

# %% [markdown]
# ### Select and Save Best YOLO Model Based on mAP Metrics

# %%
import pandas as pd

# Check if the best model weights file exists
print(os.path.exists(os.path.join(latest_subdir, "weights", "best.pt")))

# Load training results CSV
csv = pd.read_csv(os.path.join(latest_subdir, "results.csv"))

# Strip whitespace from column names
csv.columns = [c.strip() for c in csv.columns]

# Compute best epoch score (seg or det)
if "metrics/mAP50-95(M)" in csv.columns:
    combined = (csv["metrics/mAP50-95(M)"] * 0.9 + csv["metrics/mAP50(M)"] * 0.1) + \
               (csv["metrics/mAP50-95(B)"] * 0.9 + csv["metrics/mAP50(B)"] * 0.1)
    index = combined.argmax()
    best_map50_95 = float(csv["metrics/mAP50-95(M)"].values[index])
    best_map50 = float(csv["metrics/mAP50(M)"].values[index])
else:
    combined = (csv["metrics/mAP50-95(B)"] * 0.9 + csv["metrics/mAP50(B)"] * 0.1)
    index = combined.argmax()
    best_map50_95 = float(csv["metrics/mAP50-95(B)"].values[index])
    best_map50 = float(csv["metrics/mAP50(B)"].values[index])

# Copy best.pt to /content with informative name
from_path = os.path.join(latest_subdir, "weights", "best.pt")
to_name = f"{project}-{date_string}-mAP5095_{best_map50_95:.5f}-mAP50_{best_map50:.5f}.pt"
to_path = os.path.join("/content", to_name)

print("copying from", from_path, "to", to_path)
# !cp "{from_path}" "{to_path}"
# !rsync --progress "{to_path}" "{REMOTE_URL}/"

# Zip the whole run folder (latest_subdir) and upload
run_name = os.path.basename(latest_subdir)  # e.g. 2026-01-31-11_panabat-1
zip_path = os.path.join("/content", f"{project}-{run_name}.zip")

print("zipping", latest_subdir, "->", zip_path)
# !zip -r "{zip_path}" "{latest_subdir}"
# !rsync --progress "{zip_path}" "{REMOTE_URL}/"

# %%
# !rsync --progress {to_path} {REMOTE_URL}/

# %% [markdown]
# ### Training results plot

# %%
# Change working directory to HOME
# %cd {HOME}

# Display the training results plot (e.g. loss and metrics curves)
Image(filename=f'{latest_subdir}/results.png', width=1200)

# %% [markdown]
# ### Sample batch of validation predictions

# %%
# Change working directory to HOME
# %cd {HOME}

# Display a sample batch of validation predictions (visual output of model)
Image(filename=f'{latest_subdir}/val_batch0_pred.jpg', width=600)

# %% [markdown]
# # 6) Validate Custom Model
#
# This step runs **model validation** using the best trained checkpoint (`best.pt`) on the validation dataset defined in `data.yaml`. It evaluates the model's performance using standard YOLO metrics, such as:
#
# - **mAP50**: mean Average Precision at IoU threshold 0.5
# - **mAP50-95**: mean AP across IoU thresholds from 0.5 to 0.95
# - **Precision & Recall** for each class
#
# The validation results will be saved inside the specified project folder and include:
#
# - A `results.png` file with training/validation curves
# - A `confusion_matrix.png` for classification performance
# - A `val_batch0_pred.jpg` showing predicted bounding boxes on a sample batch
#
# You can use these visual and quantitative outputs to assess if the model generalizes well to unseen data. [link text](https://)

# %%
# Change working directory to HOME
# %cd {HOME}

# Display the training results plot (e.g. loss and metrics curves)
Image(filename=f'{latest_subdir}/results.png', width=1200)

# %% [markdown]
# # 7) Run Inference on Validation Images
#
# This step performs **inference (prediction)** using the best trained YOLO model (`best.pt`) on the validation image set. It is useful to **visually inspect how the model performs** on real images after training.
#
# What this does:
#
# - Removes any existing `predict` folder to avoid clutter or overwriting previous predictions
# - Runs YOLO in `predict` mode using:
#   - The best model checkpoint
#   - Images from the validation set
#   - A low confidence threshold (`conf=0.1`) to allow more predictions for visual inspection
#   - The specified image size (`imgsz`)
# - Saves predicted images (with boxes, masks, or keypoints depending on the task) in a new folder under the project directory: `runs/predict`
#
# This is especially helpful for qualitatively checking the model's detection performance, spotting failure cases, or selecting images for visualization or presentations.

# %%
# %cd {HOME}

best_ckpt = os.path.join(latest_subdir, "weights", "best.pt")
data_yaml = os.path.join(out_dir, "data.yaml")   # <-- fix: use out_dir

assert os.path.exists(best_ckpt), best_ckpt
assert os.path.exists(data_yaml), data_yaml

# !yolo task={task} mode=val model="{best_ckpt}" data="{data_yaml}" project="{project}" imgsz={resolution} line_width=1

# %% [markdown]
# ### Zip and Save Prediction Results
#
# This step creates a ZIP archive of the prediction results generated in the previous step. The archive is saved in your home directory and named using the training subdirectory name (to make it easy to track which model it came from).
#
# This makes it simple to download, share, or upload the predictions for external use (e.g., for presentations, manual inspection, or further analysis).

# %%
# Change working directory to HOME
# %cd {HOME}

best_ckpt   = os.path.join(latest_subdir, "weights", "best.pt")
valid_imgs  = os.path.join(out_dir, "valid", "images")   # <-- use out_dir (your dataset root)
pred_dir    = os.path.join(project, "predict")           # project/name

print("Model:", best_ckpt)
print("Source:", valid_imgs)
print("Will write to:", pred_dir)

# Remove any previous YOLO prediction results (safe delete)
if os.path.isdir(pred_dir):
    shutil.rmtree(pred_dir)

# Run YOLO prediction on validation images using the best model checkpoint
# !yolo task={task} mode=predict model="{best_ckpt}" project="{project}" name="predict" conf=0.1 source="{valid_imgs}" save=True imgsz={resolution} line_width=1

# %% [markdown]
# # 10) Display Sample Predictions
#
# This step randomly selects and displays 5 predicted images from the `predict` folder.
#
# Each image includes the model's output (e.g., bounding boxes, masks, or keypoints) overlaid on the validation images.
# It provides a quick **visual inspection** of model performance across different examples.
#
# This qualitative check helps identify:
# - How well the model localizes objects
# - Possible false positives or negatives
# - Class confusion or missed detections

# %%
# Find newest predict* folder for this task/project
pred_root = f"/content/datasets/runs/{task}/{project}"
pred_candidates = [p for p in glob.glob(f"{pred_root}/predict*") if os.path.isdir(p)]
assert pred_candidates, f"No predict folder found in: {pred_root}"
pred_dir = max(pred_candidates, key=os.path.getmtime)

# Randomly select up to 5 predicted images
imgs = glob.glob(f"{pred_dir}/*.jpg")
assert imgs, f"No .jpg files found in: {pred_dir}"

k = min(5, len(imgs))
files = np.random.choice(imgs, size=k, replace=False)
print(files.shape)
print("Using:", pred_dir)

for image_path in files:
    display(Image(filename=image_path, height=600))
    print()

# %%
# Wait for 30 seconds (e.g., to ensure all background tasks finish before disconnecting)
time.sleep(30)

# Gracefully disconnect the current Colab runtime session
runtime.unassign()

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Find more learning resources here
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
